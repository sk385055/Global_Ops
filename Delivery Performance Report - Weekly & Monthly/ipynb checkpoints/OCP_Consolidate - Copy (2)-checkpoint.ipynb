# %%
import os
import pandas as pd
import glob
from pyxlsb import open_workbook as open_xlsb

# %%
folder_path = r'E:\_Projects\_outputs\orders\snd' # Replace with the actual folder path

# %%
# Get a list of all files in the folder
files = glob.glob(folder_path+'\workbench_data_eumocp_wPO_2025????_v2.csv')

files.sort()

# %%
consolidated_data = pd.DataFrame()

for file in files:
    print(file)
    df=pd.read_csv(file, encoding='utf-8', low_memory=False, keep_default_na='')
    #df= df[df['Plant'].isin(['CHE','CHS','EN2','JB2'])]
    #df= df[df['Plant'].isin(['EN2','JB2'])]
    df= df[df['PID Type'].isin(['M'])]
    

    df['filref'] = os.path.basename(file)
    df = df[['PO No.','Org Code','Plant','Region','Customer_End Customer','DEMAND VAL','Booked Dt','Ship Date','Product Range','Class','PID','PID Desc','PID Type','IO No.','IO BOOKED DATE','IO SSD','filref']]
    consolidated_data = pd.concat([consolidated_data,df],axis=0)
# Out:
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250101_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250102_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250103_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250106_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250107_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250108_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250109_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250110_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250113_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250114_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250115_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250116_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250117_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250120_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250121_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250122_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250123_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250124_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250127_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250128_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250129_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250130_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250131_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250203_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250204_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250205_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250206_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250207_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250210_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250211_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250212_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250213_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250214_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250217_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250218_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250219_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250220_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250221_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250224_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250225_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250226_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250227_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250228_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250303_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250304_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250305_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250306_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250307_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250310_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250311_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250312_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250313_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250314_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250317_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250318_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250319_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250320_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250321_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250324_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250325_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250326_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250327_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250328_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250331_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250401_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250402_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250403_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250404_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250407_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250408_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250409_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250410_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250411_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250414_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250415_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250416_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250417_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250418_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250421_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250422_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250423_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250424_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250425_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250428_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250429_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250430_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250501_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250502_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250505_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250506_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250507_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250508_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250509_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250512_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250513_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250514_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250515_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250516_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250519_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250520_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250521_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250522_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250523_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250526_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250527_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250528_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250529_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250530_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250602_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250603_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250604_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250605_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250606_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250609_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250610_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250611_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250612_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250613_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250616_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250617_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250618_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250619_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250620_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250623_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250624_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250625_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250626_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250627_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250630_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250701_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250702_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250703_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250704_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250707_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250708_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250709_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250710_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250711_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250714_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250715_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250716_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250717_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250718_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250721_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250722_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250723_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250724_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250725_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250728_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250729_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250730_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250731_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250801_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250804_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250807_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250808_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250811_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250812_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250813_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250814_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250818_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250819_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250820_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250821_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250822_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250825_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250826_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250827_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250828_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250829_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250901_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250902_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250903_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250904_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250905_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250908_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250909_v2.csv
# E:\_Projects\_outputs\orders\snd\workbench_data_eumocp_wPO_20250910_v2.csv

# %%
consolidated_data.drop_duplicates(inplace=True)
#consolidated_data = consolidated_data[(consolidated_data['Supply Qty'].astype(int))>0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File e:\softwares\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File e:\softwares\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File e:\softwares\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Supply Qty'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 2
#       1 consolidated_data.drop_duplicates(inplace=True)
# ----> 2 consolidated_data = consolidated_data[(consolidated_data['Supply Qty'].astype(int))>0]
#
# File e:\softwares\anaconda3\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File e:\softwares\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Supply Qty'

# %%
# Chennai PLANT 
try:
     consolidated_data = consolidated_data[['PO No.','Org Code','Plant','Region','Customer_End Customer','DEMAND VAL','Booked Dt','Ship Date','Product Range','Class','PID','PID Desc','PID Type','IO No.','IO BOOKED DATE','IO SSD','filref']]
except:
     consolidated_data = consolidated_data[['PO No.','Org Code','Plant','Region','Customer_End Customer','DEMAND VAL','Booked Dt','Ship Date','Product Range','Class','PID','PID Desc','PID Type','IO No.','IO BOOKED DATE','IO SSD','filref']]

# %%
consolidated_data.shape[0]

# %%
consolidated_data.drop_duplicates(subset=['PO No.','Org Code','Plant','Region','Customer_End Customer','DEMAND VAL','Booked Dt','Ship Date','Product Range','Class','PID','PID Desc','PID Type','IO No.','IO BOOKED DATE','IO SSD'],keep='first',inplace=True)

# %%
consolidated_data.shape[0]

# %%
consolidated_data.to_csv(r'E:\_Projects\Consolidation of EUMOCP\ATM_V3.csv', index = False)
