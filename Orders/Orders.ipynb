# %% [markdown]
# ### Enn Previous File update Yes (Old File) = 1 | No (Current File) = 0

# %%
PD_Enn = 0

pervious_date_ENN = '20260130'

# %% [markdown]
# ### User Input

# %%
## YYYYMMDD

current_date = '20260224'

EUMOCP_File_Name ='24-Feb-2026'

Enn_File_Name = 'Open_Orders_Atleos_Feb_24'

# %% [markdown]
# ### ####################### Don't Update this part ######################

# %%
Current_date_Enn = int(current_date)

Row_Doc_file = 'workbench_data_eumocp_wPO_'+current_date+'_v2'
Doc_Chx_file = 'workbench_data_eumocp_'+current_date+'_v2'
