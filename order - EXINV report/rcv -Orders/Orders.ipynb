# %%
Enn_File_Name = 'Open Orders - 17-Jul'
Jab_File_Name = 'dolphin_atm_20240716'
EUMOCP_File_Name ='17-JUL-2024'
Current_date_Enn = 20240717
Current_date_Jab = 20240717
pervious_date_JAB = '20240524'
pervious_date_ENN = '20240527'

Row_Doc_file = 'workbench_data_eumocp_wPO_20240717_v2'
Doc_Chx_file = 'workbench_data_eumocp_20240717_v2'


#Pervious date Yes = 1 | No = 0
PD_Jab = 0
PD_Enn = 0
