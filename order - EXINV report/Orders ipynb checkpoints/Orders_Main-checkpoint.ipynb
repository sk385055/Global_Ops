# %%
# %run workbench_gf1_v2.ipynb

# %%
# %run workbench_jab_atm_v2.ipynb

# %%
# %run workbench_ocp_V2.ipynb
# Out:
# OCP_IA_EUMOCP_24-JUN-2024.xlsx
# CPU times: total: 24.8 s
# Wall time: 24.8 s
# [nan '1970Q1']
# site_name: enn; data: eumocp_20240624
# site_name: jab; data: eumocp_20240624
# 20240624

# %%
# %run workbench_rowformat_v2.ipynb

# %%
# %run workbench_doc_chx_v2.ipynb
# Out:
# workbench_data_eumocp_20240624
# (9422, 146)

# %%
# %run workbench_doc_v2.ipynb
