# %% [markdown]
# ### ###################### Don't Modify this part

# %%
# %run Orders.ipynb

# %%
date_used = None

if PD_Enn == 0:
    date_used = Current_date_Enn
else:
    date_used = int(pervious_date_ENN)

# %%
file_name = f"enn eumocp {date_used}"
# %run alloc_v2.py {file_name}

#%run alloc_v2.py enn eumocp 20250911
# Out:
# site_name: enn; data: eumocp_20250911
