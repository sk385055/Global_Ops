# %%
# %run NFC.ipynb
# Out:
# Automation Started
# C:\Users\vv185114\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Data Validation extension is not supported and will be removed
#   for idx, row in parser.parse():
# C:\Users\vv185114\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Data Validation extension is not supported and will be removed
#   for idx, row in parser.parse():
# C:\Users\vv185114\AppData\Local\Temp\ipykernel_23452\662387280.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   New_Demand['Class'] = New_Demand['Class'].astype(str)
# #################################################
#
# Duplicate config found in Tracker:
#
# ...
