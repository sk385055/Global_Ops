# %%
# %run Azure_Vs_IND_POR.ipynb
# Out:
# Index(['Demand Stream', 'Region1', 'Area2', 'Region', 'Theatre', 'Area',
#        'Country Name', 'Country Code', 'Bill to Country', 'Zone',
#        ...
#        '2024Q4 $', '2025Q1 $', '2025Q2 $', '2025Q3 $', '2025Q4 $', '2026Q1 $',
#        '2026Q2 $', '2024 Total $', '2025 Total $', '2026 Total $'],
#       dtype='object', length=102)
#
# **********************************************************
# Enter Date from Header : Dec-24
# C:\Users\vv185114\AppData\Local\Temp\3\ipykernel_4012\4063889966.py:25: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   Azure['Actual Ship Date'] = pd.to_datetime(Azure['Actual Ship Date'])
# ...
