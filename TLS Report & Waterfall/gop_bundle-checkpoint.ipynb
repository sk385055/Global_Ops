# %%
import os

import pandas as pd
import numpy as np

# %%
path = r"E:\_Projects\gop\gop_bundle\powerquery"

# %%
# append curr GOP into gop2022
# a = pd.read_excel(os.path.join(path, "gop2022.xlsx"))
# b = pd.read_excel(os.path.join(path, "curr.xlsx"))
# pd.concat([a, b]).to_excel(os.path.join(path, "gop2022.xlsx"), index=False)
# del a, b

# %%
gops = ["21Plan.xlsx", "22Plan.xlsx", "gop2022.xlsx", "curr.xlsx", "prior.xlsx"]

# %%
dfs = []
for gop in gops:
    dfs.append(pd.read_excel(os.path.join(path, gop), engine='openpyxl').iloc[:,:24])

# %%
print(dfs)
# Out:
# [     Site Scenario     Sheetname Product Group                 Offer PF  \
# 0     BUD   21Plan      Budapest           ATM        Self Serv 20 - CD
# 1     BUD   21Plan      Budapest           ATM        Self Serv 20 - CD
# 2     BUD   21Plan      Budapest           ATM        Self Serv 20 - CD
# 3     BUD   21Plan      Budapest           ATM        Self Serv 20 - CD
# 4     BUD   21Plan      Budapest           ATM        Self Serv 20 - CD
# ...   ...      ...           ...           ...                      ...
# 1903  USL   21Plan  2021 EMS MPP         ITEMS  NON-Manufacturing Items
# 1904  USL   21Plan  2021 EMS MPP         ITEMS  NON-Manufacturing Items
# 1905  USL   21Plan  2021 EMS MPP         ITEMS  NON-Manufacturing Items
# 1906  USL   21Plan  2021 EMS MPP         ITEMS  NON-Manufacturing Items
# 1907  USL   21Plan  2021 EMS MPP         ITEMS  NON-Manufacturing Items
#
#                 Range Class GOP Class  SSD       Date  ...  Exclude  \
# 0     NCR SelfServ CD  2012      2012  Jan 2021-01-01  ...       No
# 1     NCR SelfServ CD  2012      2012  Feb 2021-02-01  ...       No
# 2     NCR SelfServ CD  2012      2012  Mar 2021-03-01  ...       No
# 3     NCR SelfServ CD  2012      2012  Apr 2021-04-01  ...       No
# 4     NCR SelfServ CD  2012      2012  May 2021-05-01  ...       No
# ...               ...   ...       ...  ...        ...  ...      ...
# 1903              HHT  7777      7777  Aug 2021-08-01  ...       No
# 1904              HHT  7777      7777  Sep 2021-09-01  ...       No
# 1905              HHT  7777      7777  Oct 2021-10-01  ...       No
# 1906              HHT  7777      7777  Nov 2021-11-01  ...       No
# 1907              HHT  7777      7777  Dec 2021-12-01  ...       No
#
#      ExcludeWSP       Prod Range     Offer Prod Portfolio    Grp Flag_Discon  \
# 0            No  NCR SelfServ CD                       CD    ATM           N
# 1            No  NCR SelfServ CD                       CD    ATM           N
# 2            No  NCR SelfServ CD                       CD    ATM           N
# 3            No  NCR SelfServ CD                       CD    ATM           N
# 4            No  NCR SelfServ CD                       CD    ATM           N
# ...         ...              ...                      ...    ...         ...
# 1903         No              HHT  NON-Manufacturing Items  Other           N
# 1904         No              HHT  NON-Manufacturing Items  Other           N
# 1905         No              HHT  NON-Manufacturing Items  Other           N
# 1906         No              HHT  NON-Manufacturing Items  Other           N
# 1907         No              HHT  NON-Manufacturing Items  Other           N
#
#      Flag_Exclude Flag_USI  Show/Hide MDAYS
# 0               N         N      Show  15.0
# 1               N         N      Show  20.0
# 2               N         N      Show  22.0
# 3               N         N      Show  20.0
# 4               N         N      Show  20.0
# ...           ...       ...       ...   ...
# 1903            N         N      Show   NaN
# 1904            N         N      Show   NaN
# 1905            N         N      Show   NaN
# 1906            N         N      Show   NaN
# 1907            N         N      Show   NaN
#
# [1908 rows x 24 columns],      Site Scenario    Sheetname Product Group           Offer PF  \
# 0     BUD   22Plan     Budapest           ATM  Self Serv 20 - CD
# 1     BUD   22Plan     Budapest           ATM  Self Serv 20 - CD
# 2     BUD   22Plan     Budapest           ATM  Self Serv 20 - CD
# 3     BUD   22Plan     Budapest           ATM  Self Serv 20 - CD
# 4     BUD   22Plan     Budapest           ATM  Self Serv 20 - CD
# ...   ...      ...          ...           ...                ...
# 1497  BRI   22Plan  Bridgestone         OTHER              OTHER
# 1498  BRI   22Plan  Bridgestone         OTHER              OTHER
# 1499  BRI   22Plan  Bridgestone         OTHER              OTHER
# 1500  BRI   22Plan  Bridgestone         OTHER              OTHER
# 1501  BRI   22Plan  Bridgestone         OTHER              OTHER
#
#                 Range Class GOP Class  SSD       Date  ...  Exclude  \
# 0     NCR SelfServ CD  2012      2012  Jan 2022-01-01  ...       No
# 1     NCR SelfServ CD  2012      2012  Feb 2022-02-01  ...       No
# 2     NCR SelfServ CD  2012      2012  Mar 2022-03-01  ...       No
# 3     NCR SelfServ CD  2012      2012  Apr 2022-04-01  ...       No
# 4     NCR SelfServ CD  2012      2012  May 2022-05-01  ...       No
# ...               ...   ...       ...  ...        ...  ...      ...
# 1497            OTHER  9700      9700  Aug 2022-08-01  ...       No
# 1498            OTHER  9700      9700  Sep 2022-09-01  ...       No
# 1499            OTHER  9700      9700  Oct 2022-10-01  ...       No
# 1500            OTHER  9700      9700  Nov 2022-11-01  ...       No
# 1501            OTHER  9700      9700  Dec 2022-12-01  ...       No
#
#      ExcludeWSP       Prod Range  Offer Prod Portfolio    Grp Flag_Discon  \
# 0            No  NCR SelfServ CD                    CD    ATM           N
# 1            No  NCR SelfServ CD                    CD    ATM           N
# 2            No  NCR SelfServ CD                    CD    ATM           N
# 3            No  NCR SelfServ CD                    CD    ATM           N
# 4            No  NCR SelfServ CD                    CD    ATM           N
# ...         ...              ...                   ...    ...         ...
# 1497         No            Other                 Other  Other           N
# 1498         No            Other                 Other  Other           N
# 1499         No            Other                 Other  Other           N
# 1500         No            Other                 Other  Other           N
# 1501         No            Other                 Other  Other           N
#
#      Flag_Exclude Flag_USI  Show/Hide MDAYS
# 0               N         N      Show  10.0
# 1               N         N      Show  20.0
# 2               N         N      Show  22.0
# 3               N         N      Show  20.0
# 4               N         N      Show  20.0
# ...           ...       ...       ...   ...
# 1497            N         N      Hide  22.0
# 1498            N         N      Hide  21.0
# 1499            N         N      Hide  21.0
# 1500            N         N      Hide  20.0
# 1501            N         N      Hide  21.0
#
# [1502 rows x 24 columns],        Site         Scenario    Sheetname Product Group           Offer PF  \
# 0       BUD      GOP2021Plan     Budapest           ATM  Self Serv 20 - CD
# 1       BUD      GOP2021Plan     Budapest           ATM  Self Serv 20 - CD
# 2       BUD      GOP2021Plan     Budapest           ATM  Self Serv 20 - CD
# 3       BUD      GOP2021Plan     Budapest           ATM  Self Serv 20 - CD
# 4       BUD      GOP2021Plan     Budapest           ATM  Self Serv 20 - CD
# ...     ...              ...          ...           ...                ...
# 203318  CHE  GOP2025.11.xlsb  Chennai DOM           ATM                 MF
# 203319  CHE  GOP2025.11.xlsb  Chennai DOM           ATM                 MF
# 203320  CHE  GOP2025.11.xlsb  Chennai DOM           ATM                 MF
# 203321  CHE  GOP2025.11.xlsb  Chennai DOM           ATM                 MF
# 203322  CHE  GOP2025.11.xlsb  Chennai DOM           ATM                 MF
#
#                   Range Class GOP Class  SSD                 Date  ...  \
# 0       NCR SelfServ CD  2012      2012  Jan  2021-01-01 00:00:00  ...
# 1       NCR SelfServ CD  2012      2012  Feb  2021-02-01 00:00:00  ...
# 2       NCR SelfServ CD  2012      2012  Mar  2021-03-01 00:00:00  ...
# 3       NCR SelfServ CD  2012      2012  Apr  2021-04-01 00:00:00  ...
# 4       NCR SelfServ CD  2012      2012  May  2021-05-01 00:00:00  ...
# ...                 ...   ...       ...  ...                  ...  ...
# 203318  NCR Selfserv FF  2019      2019  Aug  2026-08-01 00:00:00  ...
# 203319  NCR Selfserv FF  2019      2019  Sep  2026-09-01 00:00:00  ...
# 203320  NCR Selfserv FF  2019      2019  Oct  2026-10-01 00:00:00  ...
# 203321  NCR Selfserv FF  2019      2019  Nov  2026-11-01 00:00:00  ...
# 203322  NCR Selfserv FF  2019      2019  Dec  2026-12-01 00:00:00  ...
#
#         Exclude ExcludeWSP       Prod Range Offer Prod Portfolio  Grp  \
# 0            No         No  NCR SelfServ CD                   CD  ATM
# 1            No         No  NCR SelfServ CD                   CD  ATM
# 2            No         No  NCR SelfServ CD                   CD  ATM
# 3            No         No  NCR SelfServ CD                   CD  ATM
# 4            No         No  NCR SelfServ CD                   CD  ATM
# ...         ...        ...              ...                  ...  ...
# 203318       No         No  NCR Selfserv FF                   MF  ATM
# 203319       No         No  NCR Selfserv FF                   MF  ATM
# 203320       No         No  NCR Selfserv FF                   MF  ATM
# 203321       No         No  NCR Selfserv FF                   MF  ATM
# 203322       No         No  NCR Selfserv FF                   MF  ATM
#
#        Flag_Discon Flag_Exclude Flag_USI  Show/Hide MDAYS
# 0                N            N         N      Show  15.0
# 1                N            N         N      Show  20.0
# 2                N            N         N      Show  22.0
# 3                N            N         N      Show  20.0
# 4                N            N         N      Show  20.0
# ...            ...          ...       ...       ...   ...
# 203318           N            N         N      Show   NaN
# 203319           N            N         N      Show   NaN
# 203320           N            N         N      Show   NaN
# 203321           N            N         N      Show   NaN
# 203322           N            N         N      Show   NaN
#
# [203323 rows x 24 columns],      Site         Scenario     Sheetname Product Group Offer PF  \
# 0     BUD  GOP2025.11.xlsb  Ennoconn Bud           ATM       CD
# 1     BUD  GOP2025.11.xlsb  Ennoconn Bud           ATM       CD
# 2     BUD  GOP2025.11.xlsb  Ennoconn Bud           ATM       CD
# 3     BUD  GOP2025.11.xlsb  Ennoconn Bud           ATM       CD
# 4     BUD  GOP2025.11.xlsb  Ennoconn Bud           ATM       CD
# ...   ...              ...           ...           ...      ...
# 1927  CHE  GOP2025.11.xlsb   Chennai DOM           ATM       MF
# 1928  CHE  GOP2025.11.xlsb   Chennai DOM           ATM       MF
# 1929  CHE  GOP2025.11.xlsb   Chennai DOM           ATM       MF
# 1930  CHE  GOP2025.11.xlsb   Chennai DOM           ATM       MF
# 1931  CHE  GOP2025.11.xlsb   Chennai DOM           ATM       MF
#
#                 Range Class GOP Class  SSD       Date  ...  Exclude  \
# 0     NCR Selfserv CD  6623      6623  Jan 2024-01-01  ...       No
# 1     NCR Selfserv CD  6623      6623  Feb 2024-02-01  ...       No
# 2     NCR Selfserv CD  6623      6623  Mar 2024-03-01  ...       No
# 3     NCR Selfserv CD  6623      6623  Apr 2024-04-01  ...       No
# 4     NCR Selfserv CD  6623      6623  May 2024-05-01  ...       No
# ...               ...   ...       ...  ...        ...  ...      ...
# 1927  NCR Selfserv FF  2019      2019  Aug 2026-08-01  ...       No
# 1928  NCR Selfserv FF  2019      2019  Sep 2026-09-01  ...       No
# 1929  NCR Selfserv FF  2019      2019  Oct 2026-10-01  ...       No
# 1930  NCR Selfserv FF  2019      2019  Nov 2026-11-01  ...       No
# 1931  NCR Selfserv FF  2019      2019  Dec 2026-12-01  ...       No
#
#      ExcludeWSP       Prod Range Offer Prod Portfolio  Grp Flag_Discon  \
# 0            No  NCR Selfserv CD                   CD  ATM           N
# 1            No  NCR Selfserv CD                   CD  ATM           N
# 2            No  NCR Selfserv CD                   CD  ATM           N
# 3            No  NCR Selfserv CD                   CD  ATM           N
# 4            No  NCR Selfserv CD                   CD  ATM           N
# ...         ...              ...                  ...  ...         ...
# 1927         No  NCR Selfserv FF                   MF  ATM           N
# 1928         No  NCR Selfserv FF                   MF  ATM           N
# 1929         No  NCR Selfserv FF                   MF  ATM           N
# 1930         No  NCR Selfserv FF                   MF  ATM           N
# 1931         No  NCR Selfserv FF                   MF  ATM           N
#
#      Flag_Exclude Flag_USI  Show/Hide MDAYS
# 0               N         N      Show   NaN
# 1               N         N      Show   NaN
# 2               N         N      Show   NaN
# 3               N         N      Show   NaN
# 4               N         N      Show   NaN
# ...           ...       ...       ...   ...
# 1927            N         N      Show   NaN
# 1928            N         N      Show   NaN
# 1929            N         N      Show   NaN
# 1930            N         N      Show   NaN
# 1931            N         N      Show   NaN
#
# [1932 rows x 24 columns],      Site         Scenario     Sheetname Product Group Offer PF  \
# 0     BUD  GOP2025.10.xlsb  Ennoconn Bud           ATM       CD
# 1     BUD  GOP2025.10.xlsb  Ennoconn Bud           ATM       CD
# 2     BUD  GOP2025.10.xlsb  Ennoconn Bud           ATM       CD
# 3     BUD  GOP2025.10.xlsb  Ennoconn Bud           ATM       CD
# 4     BUD  GOP2025.10.xlsb  Ennoconn Bud           ATM       CD
# ...   ...              ...           ...           ...      ...
# 1922  CHE  GOP2025.10.xlsb   Chennai DOM           ATM       MF
# 1923  CHE  GOP2025.10.xlsb   Chennai DOM           ATM       MF
# 1924  CHE  GOP2025.10.xlsb   Chennai DOM           ATM       MF
# 1925  CHE  GOP2025.10.xlsb   Chennai DOM           ATM       MF
# 1926  CHE  GOP2025.10.xlsb   Chennai DOM           ATM       MF
#
#                 Range Class GOP Class  SSD       Date  ...  Exclude  \
# 0     NCR Selfserv CD  6623      6623  Jan 2024-01-01  ...       No
# 1     NCR Selfserv CD  6623      6623  Feb 2024-02-01  ...       No
# 2     NCR Selfserv CD  6623      6623  Mar 2024-03-01  ...       No
# 3     NCR Selfserv CD  6623      6623  Apr 2024-04-01  ...       No
# 4     NCR Selfserv CD  6623      6623  May 2024-05-01  ...       No
# ...               ...   ...       ...  ...        ...  ...      ...
# 1922  NCR Selfserv FF  2019      2019  Aug 2026-08-01  ...       No
# 1923  NCR Selfserv FF  2019      2019  Sep 2026-09-01  ...       No
# 1924  NCR Selfserv FF  2019      2019  Oct 2026-10-01  ...       No
# 1925  NCR Selfserv FF  2019      2019  Nov 2026-11-01  ...       No
# 1926  NCR Selfserv FF  2019      2019  Dec 2026-12-01  ...       No
#
#      ExcludeWSP       Prod Range  Offer Prod Portfolio  Grp Flag_Discon  \
# 0            No  NCR Selfserv CD                    CD  ATM           N
# 1            No  NCR Selfserv CD                    CD  ATM           N
# 2            No  NCR Selfserv CD                    CD  ATM           N
# 3            No  NCR Selfserv CD                    CD  ATM           N
# 4            No  NCR Selfserv CD                    CD  ATM           N
# ...         ...              ...                   ...  ...         ...
# 1922         No  NCR Selfserv FF                    MF  ATM           N
# 1923         No  NCR Selfserv FF                    MF  ATM           N
# 1924         No  NCR Selfserv FF                    MF  ATM           N
# 1925         No  NCR Selfserv FF                    MF  ATM           N
# 1926         No  NCR Selfserv FF                    MF  ATM           N
#
#      Flag_Exclude Flag_USI  Show/Hide MDAYS
# 0               N         N      Show   NaN
# 1               N         N      Show   NaN
# 2               N         N      Show   NaN
# 3               N         N      Show   NaN
# 4               N         N      Show   NaN
# ...           ...       ...       ...   ...
# 1922            N         N      Show   NaN
# 1923            N         N      Show   NaN
# 1924            N         N      Show   NaN
# 1925            N         N      Show   NaN
# 1926            N         N      Show   NaN
#
# [1927 rows x 24 columns]]

# %%
dfs[4].columns
# Out:
# Index(['Site', 'Scenario', 'Sheetname', 'Product Group', 'Offer PF', 'Range',
#        'Class', 'GOP Class', 'SSD', 'Date', 'Accounting Period', 'SSD_Qtr',
#        'Year', 'Qty', 'Exclude', 'ExcludeWSP', 'Prod Range',
#        'Offer Prod Portfolio', 'Grp', 'Flag_Discon', 'Flag_Exclude',
#        'Flag_USI ', 'Show/Hide', 'MDAYS'],
#       dtype='object')

# %%
lst_period = ["2019Q1","2019Q2","2019Q3","2019Q4","2020Q1","2020Q2","2020Q3","2020Q4","2021Q1","2021Q2","2021Q3","2021Q4","2022Q1","2022Q2","2022Q3","2022Q4","2023Q1","2023Q2","2023Q3","2023Q4","2024Q1","2024Q2","2024Q3","2024Q4","2025Q1","2025Q2","2025Q3","2025Q4","2026Q1","2026Q2","2026Q3","2026Q4"]
lst_year = ["2019","2020","2021","2022","2023","2024","2025","2026"]

for df in dfs:
    df["Qty"] = df["Qty"].replace('0x17',0.0)
    for ssd_qtr in lst_period:
        df[ssd_qtr] = np.where(df["SSD_Qtr"] == ssd_qtr, df["Qty"], 0)
    for ssd_year in lst_year:
        df[ssd_year] = np.where(df["Year"] == ssd_year, df["Qty"], 0)
        
# for df in dfs:
#     df["Qty"] = df["Qty"].replace('0x17',0.0)
#     for ssd_qtr in df["SSD_Qtr"].drop_duplicates():
#         df[ssd_qtr] = np.where(df["SSD_Qtr"] == ssd_qtr, df["Qty"], 0)
#     for ssd_year in df["Year"].drop_duplicates():
#         df[ssd_year] = np.where(df["Year"] == ssd_year, df["Qty"], 0)

# %%
gop_bundle = pd.concat(dfs[:4])

# %%
cols = list(dfs[2].columns)
new_cols = filter(lambda x: x not in ("Scenario"), cols[:cols.index("MDAYS")])

# %%
dims = list(new_cols)
facts = cols[cols.index("MDAYS")+1:]

# %%
print(dims)
print(facts)
# Out:
# ['Site', 'Sheetname', 'Product Group', 'Offer PF', 'Range', 'Class', 'GOP Class', 'SSD', 'Date', 'Accounting Period', 'SSD_Qtr', 'Year', 'Qty', 'Exclude', 'ExcludeWSP', 'Prod Range', 'Offer Prod Portfolio', 'Grp', 'Flag_Discon', 'Flag_Exclude', 'Flag_USI ', 'Show/Hide']
# ['2019Q1', '2019Q2', '2019Q3', '2019Q4', '2020Q1', '2020Q2', '2020Q3', '2020Q4', '2021Q1', '2021Q2', '2021Q3', '2021Q4', '2022Q1', '2022Q2', '2022Q3', '2022Q4', '2023Q1', '2023Q2', '2023Q3', '2023Q4', '2024Q1', '2024Q2', '2024Q3', '2024Q4', '2025Q1', '2025Q2', '2025Q3', '2025Q4', '2026Q1', '2026Q2', '2026Q3', '2026Q4', '2019', '2020', '2021', '2022', '2023', '2024', '2025', '2026']

# %%
facts_not_2019 = [fact for fact in facts if ('2019') not in str(fact)]
facts_not_2019_2020 = [fact for fact in facts_not_2019 if ('2020') not in str(fact)]

prior_grp = dfs[4][dims + facts_not_2019_2020].fillna(0).groupby(dims).sum().reset_index()
curr_grp = dfs[3][dims + facts_not_2019_2020].fillna(0).groupby(dims).sum().reset_index()


# curr_grp = dfs[3][dims].fillna(0).groupby(dims).sum().reset_index()
# prior_grp = dfs[4][dims].fillna(0).groupby(dims).sum().reset_index()
# Out:
# C:\Users\HT185078\AppData\Local\Temp\3\ipykernel_22696\3496678094.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   curr_grp = dfs[3][dims + facts_not_2019_2020].fillna(0).groupby(dims).sum().reset_index()

# %%
# curr_grp['Date'] = curr_grp['Date'].astype('datetime64[ns]')
# prior_grp['Date'] = prior_grp['Date'].astype('datetime64[ns]')
curr_grp.to_excel(os.path.join(path, "chngs_Trailcurr.xlsx"), index=False)
prior_grp.to_excel(os.path.join(path, "chngs_Trailprior.xlsx"), index=False)

# %%
# facts_not_2019 = [fact for fact in facts if '2019' not in str(fact)]

# curr_grp = dfs[3][dims + facts_not_2019].fillna(0).groupby(dims).sum().reset_index()
# prior_grp = dfs[4][dims + facts_not_2019].fillna(0).groupby(dims).sum().reset_index()

# %%
chgs_grp = curr_grp.merge(prior_grp, how="outer", on=dims, validate="1:1")
# print(chgs_grp)
# chgs_grp.to_excel(os.path.join(path, "chngs_Trailhari.xlsx"), index=False)
curr_grp.to_excel(os.path.join(path, "chngs_Trailcurr2.xlsx"), index=False)
prior_grp.to_excel(os.path.join(path, "chngs_Trailprior2.xlsx"), index=False)

# %%
for ssd_qtr in chgs_grp["SSD_Qtr"].drop_duplicates():
    chgs_grp[ssd_qtr] = chgs_grp[ssd_qtr+"_x"].fillna(0) - chgs_grp[ssd_qtr+"_y"].fillna(0)
for ssd_year in chgs_grp["Year"].drop_duplicates():
    chgs_grp[ssd_year] = chgs_grp[str(ssd_year)+"_x"].fillna(0) - chgs_grp[str(ssd_year)+"_y"].fillna(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File e:\softwares\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File e:\softwares\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File e:\softwares\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2025Q4_x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[172], line 2
#       1 for ssd_qtr in chgs_grp["SSD_Qtr"].drop_duplicates():
# ----> 2     chgs_grp[ssd_qtr] = chgs_grp[ssd_qtr+"_x"].fillna(0) - chgs_grp[ssd_qtr+"_y"].fillna(0)
#       3 for ssd_year in chgs_grp["Year"].drop_duplicates():
#       4     chgs_grp[ssd_year] = chgs_grp[str(ssd_year)+"_x"].fillna(0) - chgs_grp[str(ssd_year)+"_y"].fillna(0)
#
# File e:\softwares\anaconda3\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File e:\softwares\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: '2025Q4_x'

# %%
cols = list(chgs_grp.columns)
new_cols = filter(lambda x: str(x)[-2:] not in ("_x", "_y"), cols)

# %%
chgs_grp = chgs_grp[list(new_cols)]
chgs_grp["Scenario"] = "Changes"

# %%
chgs_grp.to_excel(os.path.join(path, "chngs_tmp.xlsx"), index=False)

# %%
pd.concat([gop_bundle, chgs_grp]).to_excel(os.path.join(path, "gop_bundle.xlsx"), index=False)
