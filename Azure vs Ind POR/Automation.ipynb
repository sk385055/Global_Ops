# %%
# %run Azure_Vs_IND_POR.ipynb
# Out:
# **********************************************************
# Enter Date MMM-YY : Dec-25
# Pulling KA from Oracle SQL...........!
# C:\Users\nn385006\AppData\Local\Temp\4\ipykernel_10828\1756664495.py:29: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   KA = pd.read_sql(query, con=conn)
# Pulling Region from Oracle SQL...........!
# C:\Users\nn385006\AppData\Local\Temp\4\ipykernel_10828\2688549565.py:28: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   Region = pd.read_sql(query, con=conn)
# *************************************************
#
# Checking Backward 6month Shipment & Foward 12 month SSD
#
# *************************************************
#
# ...
