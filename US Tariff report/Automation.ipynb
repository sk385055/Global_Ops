# %% [markdown]
# ## Automation Process
# 1) Update Cost file in Input\\Cost\\Cost.xlsx
# 2) Save Regional TLS in CSV (UTF-8)
# 3) Save Global Doc in binary(xlsb)
# 4) Azure shipment save as Results.csv
#
# ----------------------------------------------------------------------------------
# ## Note : update KA
#
#     --> By default KA latest will be pull from oracle DB
#     --> Its not working then Download and save in Input\\SQL.csv file
#     --> open Script [US_Shipment_Bklg_Forcast.ipynb]
#             --> Search [SQL_Data = 0]
#                 --> Replace with = 1 save it [SQL_Data = 1]
#
# ----------------------------------------------------------------------------------
#  # Azure Query
#
# Select
# [Inventory Item Serial Number],
# [Inventory Item Object Identifier],
# left([Account Location Actual Ship Date],10)as [Actual Ship Date],
# [Account Name],
# Trim([Account Ship to Country Code]) as [Account Ship to Country Code],
# [Plant Code],
# [Account Sales Order Number],
# [Account Number],
# [Ship from Inventory Organization Name],
# [Inventory Organization Code]
#
# from [pub_manufacturing_certified_data_cubes_v].[Serialized Inventory Item Genealogy All Shipment Details]
#
# Where  [Account Location Actual Ship Date] >= '2025-01-01'
# and [Inventory Transaction Type Identifier] = 62
# and [Account Ship to Country Code] ='US'![image.png]

# %%
# %run US_Shipment_Bklg_Forcast.ipynb
# Out:
# **************************************************************************************
#
#                  Global Doc is Started ( Backlog Process................!)
#
# **************************************************************************************
#
# **************************************************************************************
#
#                  Global Doc is Completed ( Backlog Process................!)
#
# **************************************************************************************
#
# **************************************************************************************
#
#                  Shipment Process................!)
#
# **************************************************************************************
#
# Pulling KA from Oracle SQL...........!
# ...
