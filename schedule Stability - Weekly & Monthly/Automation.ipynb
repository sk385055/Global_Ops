# %%
run = int(input('Press 1) Weekly Report | 2) Monthly Report : '))
if run==1:
    print('\n******** Weekly Metrics Started ************\n')
    # %run Schedule_Stability_Weekly.ipynb
    
elif run==2:
     print('\n******** Monthly Metrics Started ************\n')
     # %run Schedule_Stability_Monthly.ipynb
else:
    print('\n************** Invalide Selection *************\n')
# Out:
# Press 1) Weekly Report | 2) Monthly Report : 1
#
# ******** Weekly Metrics Started ************
#
# Enter Monday date in the format (YYYY-MM-DD) :2025-12-01
# Enter Week : 49
# BUD Plan File :  ['E:\\_Projects\\Schedule Stability\\\\Input\\Weekly\\Open_Orders_Atleos_01_Dec.xlsx']
# Chennai Plan File :  ['E:\\_Projects\\Schedule Stability\\\\Input\\Weekly\\Wk01.xlsx']
# Global Doc File :  ['E:\\_Projects\\Schedule Stability\\\\Input\\Weekly\\Global DOC Atleos 20251201.xlsb']
# Chennai :  1
# BUD :  1
# Start Date : 2025-12-01
# End Date :  2025-12-07
# Chennai Start Date :  2025-11-30
# Chennai End Date :  2025-12-06
# **********************************************
# BUD Plan       :  435.0
# CHE Plan ATM   :  756.0
# **********************************************
# BUD Completion     :  462.0
# CHE ATM Completion :  935.0
# **REPOTE AUTOMATION COMPLETED**
# C:\Users\ja385000\AppData\Local\Temp\5\ipykernel_20448\3090349217.py:14: SettingWithCopyWarning:
# ...
